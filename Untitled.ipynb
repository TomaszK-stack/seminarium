# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import numpy as np

file = "D:\\semi\\source\\classical\\Brendan_Kinsella_-_Mozart_-_Sonata_No_13_In_B_Flat_Major_K333_-_I_Allegro.mp3"

y, sr = librosa.load(file, sr=48000)

librosa.feature.melspectrogram(y=y, sr=sr)

S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=12000)
S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=12000)

plt.colorbar(format='%+2.0f dB')
plt.title('Mel-spektrogram')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import librosa, librosa.display
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'librosa'

# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
scale = "D:\\semi\\source\\classical\\cinematic-time-lapse-115672.mp3"

# %%
ipd.Audio(scale)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
scale, sr = librosa.load(scale, sr = 48000)

# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import numpy as np

file = "D:\\semi\\source\\classical\\inspiring-romantic-story-121839.mp3"

y, sr = librosa.load(file, sr=48000)

librosa.feature.melspectrogram(y=y, sr=sr)

S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=12000)
S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=12000)

plt.colorbar(format='%+2.0f dB')
plt.title('Mel-spektrogram')
plt.tight_layout()
plt.show()

# %%
from mutagen.mp3 import MP3
from mutagen.id3 import ID3
from pydub import AudioSegment
# Out:
# d:\semi\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
