# %%
import sys
sys.path.append('C:\\Users\\korni\\seminarium\\semi\\Lib\\site-packages')
import sklearn
import numpy as np
from skimage.io import imread
import pandas as pd
import os
from skimage.transform import resize

# %%
test = pd.read_csv("C:\\Users\\korni\\seminarium\\semi\\data\\jazz\\bossa-nova-piano-instrumental-brasil-5732.csv")
test
# Out:
#      -8.000000000000000000e+01  -8.000000000000000000e+01.1  \
# 0                        -80.0                        -80.0
# 1                        -80.0                        -80.0
# 2                        -80.0                        -80.0
# 3                        -80.0                        -80.0
# 4                        -80.0                        -80.0
# ..                         ...                          ...
# 122                      -80.0                        -80.0
# 123                      -80.0                        -80.0
# 124                      -80.0                        -80.0
# 125                      -80.0                        -80.0
# 126                      -80.0                        -80.0
#
#      -8.000000000000000000e+01.2  -8.000000000000000000e+01.3  \
# 0                          -80.0                        -80.0
# 1                          -80.0                        -80.0
# 2                          -80.0                        -80.0
# 3                          -80.0                        -80.0
# 4                          -80.0                        -80.0
# ..                           ...                          ...
# 122                        -80.0                        -80.0
# 123                        -80.0                        -80.0
# 124                        -80.0                        -80.0
# 125                        -80.0                        -80.0
# 126                        -80.0                        -80.0
#
#      -8.000000000000000000e+01.4  -8.000000000000000000e+01.5  \
# 0                          -80.0                        -80.0
# 1                          -80.0                        -80.0
# 2                          -80.0                        -80.0
# 3                          -80.0                        -80.0
# 4                          -80.0                        -80.0
# ..                           ...                          ...
# 122                        -80.0                        -80.0
# 123                        -80.0                        -80.0
# 124                        -80.0                        -80.0
# 125                        -80.0                        -80.0
# 126                        -80.0                        -80.0
#
#      -8.000000000000000000e+01.6  -8.000000000000000000e+01.7  \
# 0                          -80.0                        -80.0
# 1                          -80.0                        -80.0
# 2                          -80.0                        -80.0
# 3                          -80.0                        -80.0
# 4                          -80.0                        -80.0
# ..                           ...                          ...
# 122                        -80.0                        -80.0
# 123                        -80.0                        -80.0
# 124                        -80.0                        -80.0
# 125                        -80.0                        -80.0
# 126                        -80.0                        -80.0
#
#      -8.000000000000000000e+01.8  -8.000000000000000000e+01.9  ...  \
# 0                          -80.0                        -80.0  ...
# 1                          -80.0                        -80.0  ...
# 2                          -80.0                        -80.0  ...
# 3                          -80.0                        -80.0  ...
# 4                          -80.0                        -80.0  ...
# ..                           ...                          ...  ...
# 122                        -80.0                        -80.0  ...
# 123                        -80.0                        -80.0  ...
# 124                        -80.0                        -80.0  ...
# 125                        -80.0                        -80.0  ...
# 126                        -80.0                        -80.0  ...
#
#      -2.284393119812011719e+01  -2.617239379882812500e+01  \
# 0                   -22.765251                 -17.912174
# 1                   -22.380484                 -15.158136
# 2                   -25.265816                 -16.418715
# 3                   -24.276745                 -24.242350
# 4                   -25.066559                 -21.343460
# ..                         ...                        ...
# 122                 -71.854431                 -56.093807
# 123                 -80.000000                 -65.341377
# 124                 -80.000000                 -80.000000
# 125                 -80.000000                 -80.000000
# 126                 -80.000000                 -80.000000
#
#      -2.896388053894042969e+01  -2.619318389892578125e+01  \
# 0                   -11.369175                 -12.235416
# 1                    -7.400188                  -7.705090
# 2                   -14.010447                 -18.164001
# 3                   -25.473856                 -23.984831
# 4                   -19.731464                 -19.012844
# ..                         ...                        ...
# 122                 -55.179108                 -61.412991
# 123                 -63.601601                 -71.764320
# 124                 -80.000000                 -80.000000
# 125                 -80.000000                 -80.000000
# 126                 -80.000000                 -80.000000
#
#      -2.915193748474121094e+01  -2.997501754760742188e+01  \
# 0                   -13.582409                 -16.216333
# 1                   -11.497952                 -13.784996
# 2                   -21.544182                 -20.612492
# 3                   -24.178066                 -23.736732
# 4                   -19.480171                 -18.384491
# ..                         ...                        ...
# 122                 -63.422859                 -68.944199
# 123                 -78.353439                 -80.000000
# 124                 -80.000000                 -80.000000
# 125                 -80.000000                 -80.000000
# 126                 -80.000000                 -80.000000
#
#      -2.957104492187500000e+01  -3.033602905273437500e+01  \
# 0                   -16.832214                 -17.845173
# 1                   -15.279564                 -18.002651
# 2                   -19.772718                 -20.438772
# 3                   -24.670177                 -24.021111
# 4                   -18.622417                 -18.279884
# ..                         ...                        ...
# 122                 -72.118919                 -77.581131
# 123                 -80.000000                 -80.000000
# 124                 -80.000000                 -80.000000
# 125                 -80.000000                 -80.000000
# 126                 -80.000000                 -80.000000
#
#      -2.960811996459960938e+01  -3.168612098693847656e+01
# 0                   -20.877689                 -21.870852
# 1                   -20.782606                 -21.017906
# 2                   -20.755424                 -23.342224
# 3                   -24.653252                 -27.797970
# 4                   -19.086861                 -21.762169
# ..                         ...                        ...
# 122                 -75.178635                 -69.758133
# 123                 -78.075424                 -71.633713
# 124                 -80.000000                 -76.131432
# 125                 -80.000000                 -80.000000
# 126                 -80.000000                 -80.000000
#
# [127 rows x 2375 columns]

# %%
dest_path = "C:\\Users\\korni\\seminarium\\semi\\data"
data_X = []
data_Y = []
y = 0
list = ['latino', 'rock', 'jazz', 'classical']

# for folder in os.listdir(dest_path):
for folder in list:
    csv_path = os.path.join(dest_path, folder)
    for file in os.listdir(csv_path):
        data = pd.read_csv(os.path.join(csv_path, file))
        if data.shape == (127, 2375):
            data_X.append(data)
            data_Y.append(folder)
data_XP = np.array(data_X)

new_data_x = data_XP.reshape(150,2375*127)

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=3, shuffle=True)
kf
new_data_y = np.array(data_Y)

# %%
from sklearn.svm import LinearSVC
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier
def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test,y_test)

# %%
for train_index, test_index in kf.split(data_X):
    X_train, X_test, y_train, y_test =  new_data_x[train_index], new_data_x[test_index], new_data_y[train_index], new_data_y[test_index]
    print(get_score(GradientBoostingClassifier(), X_train,X_test,y_train,y_test))
    print(get_score(RandomForestClassifier(), X_train,X_test,y_train,y_test))
    print(get_score(LinearSVC(), X_train,X_test,y_train,y_test))
# Out:
# 0.46
# 0.44
# 0.62
# 0.48
# 0.68
# C:\Users\korni\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.66
